# %%
import pandas as pd

# %%
data = pd.read_csv("prem.csv")
data.head()
# Out:
#         home_team  home_goals  home_xG home_posession home_passing_accuracy  \
# 0       Liverpool           4      1.7            57%                   79%
# 1  Manchester Utd           2      1.6            46%                   79%
# 2         Arsenal           3      2.4            59%                   83%
# 3         Everton           0      0.9            70%                   81%
# 4         Burnley           2      1.5            42%                   74%
#
#    home_shots_on_target  home_shots  home_saves  home_fouls  home_corners  \
# 0                     7          15           5          10            11
# 1                     5           7           3          18             2
# 2                     4          20           7          13             9
# 3                     3          16           0          10            12
# 4                     6          13           2          12             7
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1140 entries, 0 to 1139
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   home_team              1140 non-null   object
#  1   home_goals             1140 non-null   int64
#  2   home_xG                1140 non-null   float64
#  3   home_posession         1140 non-null   object
#  4   home_passing_accuracy  1140 non-null   object
#  5   home_shots_on_target   1140 non-null   int64
#  6   home_shots             1140 non-null   int64
#  7   home_saves             1140 non-null   int64
#  8   home_fouls             1140 non-null   int64
#  9   home_corners           1140 non-null   int64
#  10  home_crosses           1140 non-null   int64
#  11  home_touches           1140 non-null   int64
#  12  home_tackles           1140 non-null   int64
#  13  home_interceptions     1140 non-null   int64
# ...

# %% [markdown]
# Split into 2 dataframes: one for all home games, the other for all away games.

# %%
home_statistics = data[["home_team", "home_goals", "home_xG", "home_posession", "home_passing_accuracy", 
                             "home_shots_on_target", "home_shots", "home_saves", "home_fouls", "home_corners", 
                             "home_crosses", "home_touches", "home_tackles", "home_interceptions", 
                              "home_aerials_won", "home_clearances", "home_offsides", "home_goal_kicks", 
                             "home_throw_ins", "home_long_balls"]].copy()
home_statistics.head()
# Out:
#         home_team  home_goals  home_xG home_posession home_passing_accuracy  \
# 0       Liverpool           4      1.7            57%                   79%
# 1  Manchester Utd           2      1.6            46%                   79%
# 2         Arsenal           3      2.4            59%                   83%
# 3         Everton           0      0.9            70%                   81%
# 4         Burnley           2      1.5            42%                   74%
#
#    home_shots_on_target  home_shots  home_saves  home_fouls  home_corners  \
# 0                     7          15           5          10            11
# 1                     5           7           3          18             2
# 2                     4          20           7          13             9
# 3                     3          16           0          10            12
# 4                     6          13           2          12             7
#
# ...

# %%
away_statistics = data[["away_team", "away_goals", "away_xG", "away_possession", "away_passing_accuracy", 
                             "away_shots_on_target", "away_shots", "away_saves", "away_fouls", "away_corners", 
                             "away_crosses", "away_touches", "away_tackles", "away_interceptions", 
                              "away_aerials_won", "away_clearances", "away_offsides", "away_goal_kicks", 
                              "away_throw_ins", "away_long_balls"]].copy()
away_statistics.head()
# Out:
#         away_team  away_goals  away_xG away_possession away_passing_accuracy  \
# 0    Norwich City           1      1.0             43%                   77%
# 1  Leicester City           1      1.1             54%                   79%
# 2     Aston Villa           2      1.1             41%                   78%
# 3   Sheffield Utd           2      0.2             30%                   62%
# 4    Norwich City           0      0.6             58%                   81%
#
#    away_shots_on_target  away_shots  away_saves  away_fouls  away_corners  \
# 0                     6          13           3          12             2
# 1                     4          13           4           9             2
# 2                     9          14           2          15             4
# 3                     1           2           3          10             3
# 4                     2          11           4          11             3
#
# ...

# %% [markdown]
# Standardize all column names in both data frames to concatenate home data with away data.

# %%
home_statistics.columns = ["team", "goals", "xG", "possession", "passing_accuracy", "shots_on_target", "shots", 
                           "saves", "fouls", "corners", "crosses", "touches", "tackles", "interceptions", 
                           "aerials_won", "clearances", "offsides", "goal_kicks", "throw_ins", "long_balls"]
home_statistics.head()
# Out:
#              team  goals   xG possession passing_accuracy  shots_on_target  \
# 0       Liverpool      4  1.7        57%              79%                7
# 1  Manchester Utd      2  1.6        46%              79%                5
# 2         Arsenal      3  2.4        59%              83%                4
# 3         Everton      0  0.9        70%              81%                3
# 4         Burnley      2  1.5        42%              74%                6
#
#    shots  saves  fouls  corners  crosses  touches  tackles  interceptions  \
# 0     15      5     10       11       15      633       24             11
# 1      7      3     18        2        8      625       19             14
# 2     20      7     13        9       17      604       18              7
# 3     16      0     10       12       24      719       14              5
# 4     13      2     12        7       17      520       19             10
#
# ...

# %%
away_statistics.columns = ["team", "goals", "xG", "possession", "passing_accuracy", "shots_on_target", "shots", 
                           "saves", "fouls", "corners", "crosses", "touches", "tackles", "interceptions", 
                           "aerials_won", "clearances", "offsides", "goal_kicks", "throw_ins", "long_balls"]
away_statistics.head()
# Out:
#              team  goals   xG possession passing_accuracy  shots_on_target  \
# 0    Norwich City      1  1.0        43%              77%                6
# 1  Leicester City      1  1.1        54%              79%                4
# 2     Aston Villa      2  1.1        41%              78%                9
# 3   Sheffield Utd      2  0.2        30%              62%                1
# 4    Norwich City      0  0.6        58%              81%                2
#
#    shots  saves  fouls  corners  crosses  touches  tackles  interceptions  \
# 0     13      3     12        2        5      537       17             10
# 1     13      4      9        2       19      676       16             12
# 2     14      2     15        4       23      470       18              9
# 3      2      3     10        3        8      411       22              5
# 4     11      4     11        3        8      657       23              2
#
# ...

# %% [markdown]
# Concatenate home_statistics and away_statistics to aggregate all football match data.

# %%
all_statistics = pd.concat([home_statistics, away_statistics], ignore_index = True)
all_statistics.head()
# Out:
#              team  goals   xG possession passing_accuracy  shots_on_target  \
# 0       Liverpool      4  1.7        57%              79%                7
# 1  Manchester Utd      2  1.6        46%              79%                5
# 2         Arsenal      3  2.4        59%              83%                4
# 3         Everton      0  0.9        70%              81%                3
# 4         Burnley      2  1.5        42%              74%                6
#
#    shots  saves  fouls  corners  crosses  touches  tackles  interceptions  \
# 0     15      5     10       11       15      633       24             11
# 1      7      3     18        2        8      625       19             14
# 2     20      7     13        9       17      604       18              7
# 3     16      0     10       12       24      719       14              5
# 4     13      2     12        7       17      520       19             10
#
# ...

# %%
all_statistics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2280 entries, 0 to 2279
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   team              2280 non-null   object
#  1   goals             2280 non-null   int64
#  2   xG                2280 non-null   float64
#  3   possession        2280 non-null   object
#  4   passing_accuracy  2280 non-null   object
#  5   shots_on_target   2280 non-null   int64
#  6   shots             2280 non-null   int64
#  7   saves             2280 non-null   int64
#  8   fouls             2280 non-null   int64
#  9   corners           2280 non-null   int64
#  10  crosses           2280 non-null   int64
#  11  touches           2280 non-null   int64
#  12  tackles           2280 non-null   int64
#  13  interceptions     2280 non-null   int64
#  14  aerials_won       2280 non-null   int64
#  15  clearances        2280 non-null   int64
# ...

# %% [markdown]
# The "possession" and "passing_accuracy" columns have data type "object". We will express the percentages by converting the strings to floating point numbers.

# %%
all_statistics["possession"] = all_statistics["possession"].str.rstrip("%").astype("float") / 100.0
all_statistics["passing_accuracy"] = all_statistics["passing_accuracy"].str.rstrip("%").astype("float") / 100.0
all_statistics.head()
# Out:
#              team  goals   xG  possession  passing_accuracy  shots_on_target  \
# 0       Liverpool      4  1.7        0.57              0.79                7
# 1  Manchester Utd      2  1.6        0.46              0.79                5
# 2         Arsenal      3  2.4        0.59              0.83                4
# 3         Everton      0  0.9        0.70              0.81                3
# 4         Burnley      2  1.5        0.42              0.74                6
#
#    shots  saves  fouls  corners  crosses  touches  tackles  interceptions  \
# 0     15      5     10       11       15      633       24             11
# 1      7      3     18        2        8      625       19             14
# 2     20      7     13        9       17      604       18              7
# 3     16      0     10       12       24      719       14              5
# 4     13      2     12        7       17      520       19             10
#
# ...

# %%
all_statistics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2280 entries, 0 to 2279
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   team              2280 non-null   object
#  1   goals             2280 non-null   int64
#  2   xG                2280 non-null   float64
#  3   possession        2280 non-null   float64
#  4   passing_accuracy  2280 non-null   float64
#  5   shots_on_target   2280 non-null   int64
#  6   shots             2280 non-null   int64
#  7   saves             2280 non-null   int64
#  8   fouls             2280 non-null   int64
#  9   corners           2280 non-null   int64
#  10  crosses           2280 non-null   int64
#  11  touches           2280 non-null   int64
#  12  tackles           2280 non-null   int64
#  13  interceptions     2280 non-null   int64
#  14  aerials_won       2280 non-null   int64
#  15  clearances        2280 non-null   int64
# ...

# %%
all_statistics.to_csv("stats1.csv", index=False)
